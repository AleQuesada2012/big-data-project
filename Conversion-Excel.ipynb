# %% [markdown]
# # Cuaderno Auxiliar
# ## Proposito: ejecutarse una sola vez para convertir los datasets originales a .CSV
# Los datasets originales se encuentran en `datasets/`, y estan en formato `.xlsx`
# Para evitar tener que cargar desde excel los datos cada vez que se ejecuta el cuaderno, se crea este espacio donde se convierten una unica vez para dejarlos en `.csv` con ayuda de Pandas.

# %%
# !pip install openpyxl --quiet
import pandas as pd

# %%
gtd = pd.read_excel("datasets/GTD.xlsx", engine='openpyxl')
gtd
# Out:
#              eventid  iyear  imonth  iday           approxdate  extended  \
# 0       197000000001   1970       7     2                  NaN         0
# 1       197000000002   1970       0     0                  NaN         0
# 2       197001000001   1970       1     0                  NaN         0
# 3       197001000002   1970       1     0                  NaN         0
# 4       197001000003   1970       1     0                  NaN         0
# ...              ...    ...     ...   ...                  ...       ...
# 209701  202012310015   2020      12    31  2020-12-31 00:00:00         0
# 209702  202012310016   2020      12    31  2020-12-31 00:00:00         0
# 209703  202012310017   2020      12    31                  NaN         0
# 209704  202012310018   2020      12    31                  NaN         0
# 209705  202012310019   2020      12    31                  NaN         1
#
#        resolution  country         country_txt  region  ... addnotes  \
# ...

# %%
wgi_raw = pd.read_excel("datasets/WGI.xlsx", sheet_name="Data", engine="openpyxl")
wgi_raw
# Out:
#                                            Country Name Country Code  \
# 0                                           Afghanistan          AFG
# 1                                           Afghanistan          AFG
# 2                                           Afghanistan          AFG
# 3                                           Afghanistan          AFG
# 4                                           Afghanistan          AFG
# ...                                                 ...          ...
# 1070                                                NaN          NaN
# 1071                                                NaN          NaN
# 1072                                                NaN          NaN
# 1073  Data from database: Worldwide Governance Indic...          NaN
# 1074                           Last Updated: 11/05/2024          NaN
#
#                              Series Name Series Code 1996 [YR1996]  \
# 0        Control of Corruption: Estimate      CC.EST     -1.291705
# ...

# %% [markdown]
# ### Guardado en CSV para lecturas futuras (mas rapido que usar openpyxl para cargar a memoria)

# %%
gtd.to_csv("datasets/GTD.csv", index=False)
wgi_raw.to_csv("datasets/WGI.csv", index=False)
